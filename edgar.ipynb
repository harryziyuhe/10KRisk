# %%
import warnings
from sec_downloader import Downloader
import sec_parser as sp
from sec_parser.semantic_tree import render

# %%
dl = Downloader("UCSD", "zih028@ucsd.edu")
html = dl.get_filing_html(ticker = "AAPL", form = "10-Q")
parser = sp.Edgar10QParser()
elements: list = parser.parse(html)
tree = sp.TreeBuilder().build(elements)

# %%
metadata = dl.get_filing_metadatas("NFLX")
metadata
# Out:
# [FilingMetadata(accession_number='0001065280-24-000200', form_type='10-Q', primary_doc_url='https://www.sec.gov/Archives/edgar/data/1065280/000106528024000200/nflx-20240630.htm', items='', primary_doc_description='10-Q', filing_date='2024-07-19', report_date='2024-06-30', cik='0001065280', company_name='NETFLIX INC', tickers=[Ticker(symbol='NFLX', exchange='Nasdaq')])]

# %%
print(render(list(tree)))
# Out:
# TopSectionTitle: PART I  —  FINANCIAL INFORMATION
# ├── TopSectionTitle: Item 1.    Financial Statements
# │   ├── TitleElement: CONDENSED CONSOLIDATED STATEMENTS OF OPERATIONS (Unaudited)
# │   │   ├── SupplementaryText: (In millions, except number of ...ousands, and per-share amounts)
# │   │   ├── TableElement: Table with ~24 rows, ~80 numbers, and 1058 characters.
# │   │   └── SupplementaryText: See accompanying Notes to Conde...solidated Financial Statements.
# │   ├── TitleElement: CONDENSED CONSOLIDATED STATEMEN...OMPREHENSIVE INCOME (Unaudited)
# │   │   ├── SupplementaryText: (In millions)
# │   │   ├── TableElement: Table with ~13 rows, ~44 numbers, and 969 characters.
# │   │   └── SupplementaryText: See accompanying Notes to Conde...solidated Financial Statements.
# │   ├── TitleElement: CONDENSED CONSOLIDATED BALANCE SHEETS (Unaudited)
# │   │   ├── SupplementaryText: (In millions, except number of ...ed in thousands, and par value)
# ...

# %%
elements
# Out:
# [IntroductorySectionElement<table>,
#  TopSectionTitle[L0]<span>,
#  TopSectionTitle[L1]<span>,
#  TitleElement[L0]<div>,
#  TextElement<div>,
#  TitleElement[L0]<div>,
#  TitleElement[L1]<div>,
#  TextElement<div>,
#  TitleElement[L1]<div>,
#  TextElement<div>,
#  TitleElement[L1]<div>,
#  TextElement<div>,
#  TitleElement[L1]<div>,
#  TextElement<sec-parser-merged-text>,
#  TitleElement[L0]<div>,
#  TitleElement[L1]<div>,
#  TextElement<div>,
#  TitleElement[L1]<div>,
#  TextElement<div>,
#  TitleElement[L1]<div>,
#  TextElement<div>,
#  TitleElement[L1]<div>,
#  TextElement<sec-parser-merged-text>,
#  TitleElement[L1]<div>,
#  TextElement<div>,
#  TitleElement[L0]<div>,
#  TextElement<div>,
#  TitleElement[L0]<div>,
#  TextElement<div>,
#  TitleElement[L0]<div>,
#  TextElement<sec-parser-merged-text>,
#  TitleElement[L0]<div>,
#  TextElement<sec-parser-merged-text>,
#  TitleElement[L0]<div>,
#  TextElement<div>,
#  TitleElement[L0]<div>,
#  TextElement<sec-parser-merged-text>,
# ...
